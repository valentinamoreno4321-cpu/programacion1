# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinamoreno4321-cpu/programacion1/blob/main/quiz_26_de_marzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hacer un codigo adicionalmente al modulo de promedio vamos a importar la moda

# %%
# %%writefile pedirnotas.py
def pedir_normbre():
    return input("Ingrese el nombre del estudiante: ")

def pedir_notas():
    n1 = float(input("Nota 1: "))
    n2 = float(input("Nota 2: "))
    n3 = float(input("Nota 3: "))
    n4 = float(input("Nota 4: "))
    return n1, n2, n3, n4
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1,n2,n3,n4):
    return (n1+n2+n3+n4)/4

def calcular_mediana(n1,n2,n3,n4):
    return statistics.median([n1,n2,n3,n4])

def calcular_moda(n1,n2,n3,n4):
    return statistics.mode([n1,n2,n3,n4])
# Out:
# Overwriting promedio.py

# %%
import pedirnotas

# %%
import importlib
importlib.reload(pedirnotas)
nombre = pedirnotas.pedir_normbre()
# Out:
# Ingrese el nombre del estudiante: Valentina

# %%
nombre
# Out:
# 'Valentina'

# %%
notas = pedirnotas.pedir_notas()
# Out:
# Nota 1: 2
# Nota 2: 2
# Nota 3: 3
# Nota 4: 4

# %%
notas
# Out:
# (2.0, 2.0, 3.0, 4.0)

# %%
import promedio
n1,n2,n3,n4 = notas

# %%
import importlib
importlib.reload(promedio)
prom = promedio.calcular_promedio(n1,n2,n3,n4)
mediana = promedio.calcular_mediana(n1,n2,n3,n4)
moda = promedio.calcular_moda(n1,n2,n3,n4)

print("Estudiante: ", nombre)
print("Promedio: ", prom)
print("Mediana: ", mediana)
print("Moda: ", moda)

if prom >= 3:
    print("Aprobó")
else:
    print("Reprobó")
# Out:
# Estudiante:  Valentina
# Promedio:  2.75
# Mediana:  2.5
# Moda:  2.0
# Reprobó
