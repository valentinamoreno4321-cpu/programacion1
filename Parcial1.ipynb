# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinamoreno4321-cpu/programacion1/blob/main/Parcial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Nombre: Valentina Moreno Oviedo
#
# ## Código:2221990
#
# # Parte II:

# %% [markdown]
# Instrucción 1: Construya dos conjuntos A y B en Python con valores enteros de su elección. Los
# conjuntos deben cumplir que tengan al menos dos elementos en común y al menos un elemento
# diferente entre ellos. Una vez definidos los conjuntos, utilice el siguiente método:

# %%
A={1,2,3}
B={1,2,4}

# %%
A.difference(B)
# Out:
# {3}

# %% [markdown]
# El metodo **difference** nos permite obtener los elementos de A que no estan en B, para mi casa obtenemos el conjunto unitario {3} pues el unico elemento de A que no esta en B es 3

# %%
A.symmetric_difference(B)
# Out:
# {3, 4}

# %% [markdown]
# El metodo **symmetric_difference** nos devuelve todos lo elementos que no tienen en comun los dos conjuntos, en mi caso obtenemos el conjunto{3,4} pues son los dos elementos que no estan simultaneamente en los dos conjuntos

# %% [markdown]
# Instrucción 2: Defina dos conjuntos A y B con valores de su elección, de manera que todos los
# elementos de B estén contenidos dentro del conjunto A. Posteriormente utilice el siguiente método:

# %%
A={1,2,3,4}
B={1,2,3}

# %%
A.issuperset(B)
# Out:
# True

# %% [markdown]
# El metodo **.issuperset** nos permite saber si un conjunto es un super conjunto de otro, es decir en nuestro caso nos permite sabe que B es subconjunto de A o que A es super conjunto de B lo que significa que todos los elementos de B estan incluidos en A, nos devulve un bool, en nuestro caso es verdadero pues todos los elementos de B estan contenidos en A

# %%
A.isdisjoint(B)
# Out:
# False

# %% [markdown]
# El metodo **isdisjoint** nos permite saber si un conjunto en este caso A es sub

# %% [markdown]
# Instrucción 3: Defina un diccionario llamado datos2 con al menos dos pares clave:valor de su
# elección. Posteriormente utilice la siguiente instrucción de Python:

# %%
datos2={1:"a",2:"b"}

# %%
datos2.update({3:"c"})
print(datos2)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# El metodo **update.** nos permite actualizar nuestro diccionario permitiendonos agregar nuevas claves:valor

# %%
datos2.update({2:"h"})
print(datos2)
# Out:
# {1: 'a', 2: 'h', 3: 'c'}

# %% [markdown]
# El meotodo update nos permite tambein modificar el valor de una clave ya antes definida

# %%
datos2.update({1:"a"})
print(datos2)
# Out:
# {1: 'a', 2: 'h', 3: 'c'}

# %% [markdown]
# Si agregamos una clave:valor repetida no pasa nada el diccionario queda exactamente igual pues este meotodo nos permite cambiar o actualizar y como le estamos pidiendo que actualice la quue ya esta por lo mismo no cambia nada

# %% [markdown]
# Instrucción 4: Defina un diccionario llamado datos3 con al menos dos pares clave:valor de su
# elección. Posteriormente implemente la siguiente instrucción de Python:

# %%
datos3={1:"a",2:"b"}

# %%
datos3.setdefault(3, "c")
# Out:
# 'c'

# %% [markdown]
# El metodo setdefault nos devulve un valor para una clave sin importar que no este definida en nuestro diccionario

# %%
datos3.setdefault(1, "c")
# Out:
# 'a'

# %% [markdown]
# Si anoto una clave del diccionario, pero con un valor diferente el metodo me devuelve el valor que esta definido en mi diccionario inicialmente

# %%
datos3.setdefault(1, "a")
# Out:
# 'a'

# %% [markdown]
# Me devuelve el valor de mi dicionario original

# %% [markdown]
# # Parte III:

# %% [markdown]
# Código 1: Diseñe una función en Python que cumpla con las siguientes condiciones:
#
# *Permita recibir como entrada diferentes tipos de datos (números enteros, decimales o texto).
#
# *Verifique que el número sea natural (entero y mayor o igual a cero).
#
# *Recorra los números desde 0 hasta m:
# - Para 0 y 1, imprima el número.
# - Para los demás, determine si son primos o no.
# - Si no es primo, muestre una factorización básica.
# Ejecute la función con la entrada m = 5 y m = "a"

# %%
def reconoce(m):
  try:
    m=float(m)
    if m.is_integer() and m > 0:
      for n in range(0, int(m + 1)):
        if n == 1 or n == 0:
          print("El número es ", n)
        else:
          for x in range(2, n):
            if n % x == 0:
              print(n, 'es igual a', x, '*', n // x)
              break
          else: # Este else corresponde al for, no al if
           print(n, 'es un número primo')
    else:
     print("El número no es natural")
  except ValueError:
    print("El valor ingresado no es un número")

# %%
reconoce(5)
# Out:
# El número es  0
# El número es  1
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo

# %%
reconoce("a")
# Out:
# El valor ingresado no es un número

# %% [markdown]
# Codigo 2

# %%
def contador_vocales1(palabra):
 letras = "aeiou"
 letras1= letras.upper()
 numeros = "0123456789"
 consonantes = "bcdfghjklmnñpqrstvwxyz"
 consonantes1 = consonantes.upper()
 contador = 0
 contador1 = 0
 contador2 = 0
 contador3 = 0
 contador4 = 0
 contador5=0

 for letra in palabra:
  if letra in letras:
    contador += 1
  elif letra in letras1:
    contador1 += 1
  elif letra in numeros:
    contador2 += 1
  elif letra in consonantes:
    contador3 += 1
  elif letra in consonantes1:
    contador4 += 1
  else:contador5 += 1
 return({"Cantidad de vocales minusculas:": contador,
 "Cantidad de vocales mayusculas:": contador1,
 "Cantidad de numeros:": contador2,
 "Cantidad de consonantes minusculas:": contador3,
  "Cantidad de consonantes mayusculas:": contador4,
"Cantidad decaracteres especiales:": contador4})

# %%
palabra=input("Ingrese una cadena: ")
contador_vocales1(palabra)
# Out:
# Ingrese una cadena: Gat123? d
# {'Cantidad de vocales minusculas:': 1,
#  'Cantidad de vocales mayusculas:': 0,
#  'Cantidad de numeros:': 3,
#  'Cantidad de consonantes minusculas:': 2,
#  'Cantidad de consonantes mayusculas:': 1,
#  'Cantidad decaracteres especiales:': 1}
